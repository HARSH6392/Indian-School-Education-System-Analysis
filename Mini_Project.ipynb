# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSH6392/Indian-School-Education-System-Analysis/blob/main/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
dropout=pd.read_csv("/content/drive/MyDrive/Datasets/dropout-ratio-2012-2015.csv")
gross=pd.read_csv("/content/drive/MyDrive/Datasets/gross-enrollment-ratio-2013-2016.csv")
comps=pd.read_csv("/content/drive/MyDrive/Datasets/percentage-of-schools-with-comps-2013-2016.csv")
elect=pd.read_csv("/content/drive/MyDrive/Datasets/percentage-of-schools-with-electricity-2013-2016.csv")
water=pd.read_csv('/content/drive/MyDrive/Datasets/percentage-of-schools-with-water-facility-2013-2016.csv')

# %%
gross
# Out:
#                       State_UT  ... Higher_Secondary_Total
# 0    Andaman & Nicobar Islands  ...                 101.28
# 1               Andhra Pradesh  ...                   60.3
# 2            Arunachal Pradesh  ...                  65.27
# 3                        Assam  ...                  32.94
# 4                        Bihar  ...                   23.7
# ..                         ...  ...                    ...
# 105                    Tripura  ...                   43.4
# 106              Uttar Pradesh  ...                  63.75
# 107                Uttaranchal  ...                  80.36
# 108                West Bengal  ...                  49.95
# 109                  All India  ...                  54.21
#
# [110 rows x 14 columns]

# %%
dropout
# Out:
#            State_UT     year  ... HrSecondary_Girls HrSecondary_Total
# 0     A & N Islands  2012-13  ...             10.15             14.14
# 1     A & N Islands  2013-14  ...              12.2             15.87
# 2     A & N Islands  2014-15  ...             12.21             16.93
# 3    Andhra Pradesh  2012-13  ...                NR              0.35
# 4    Andhra Pradesh  2013-14  ...             10.85             11.79
# ..              ...      ...  ...               ...               ...
# 105     West Bengal  2013-14  ...              7.76               7.9
# 106     West Bengal  2014-15  ...              8.04              8.11
# 107       All India  2012-13  ...                NR                NR
# 108       All India  2013-14  ...              1.61              1.54
# 109       All India  2014-15  ...                NR                NR
#
# [110 rows x 14 columns]

# %%
comps
# Out:
#                       State_UT     year  ...  HrSec_Only  All Schools
# 0    Andaman & Nicobar Islands  2013-14  ...        0.00        53.06
# 1    Andaman & Nicobar Islands  2014-15  ...        0.00        57.25
# 2    Andaman & Nicobar Islands  2015-16  ...        0.00        57.00
# 3               Andhra Pradesh  2013-14  ...       19.32        29.57
# 4               Andhra Pradesh  2014-15  ...       41.60        28.06
# ..                         ...      ...  ...         ...          ...
# 105                West Bengal  2014-15  ...       66.67        12.13
# 106                West Bengal  2015-16  ...       66.67        12.67
# 107                  All India  2013-14  ...       26.65        24.08
# 108                  All India  2014-15  ...       47.96        26.42
# 109                  All India  2015-16  ...       55.72        27.31
#
# [110 rows x 13 columns]

# %%
dropout.head()
# Out:
#          State_UT     year  ... HrSecondary_Girls HrSecondary_Total
# 0   A & N Islands  2012-13  ...             10.15             14.14
# 1   A & N Islands  2013-14  ...              12.2             15.87
# 2   A & N Islands  2014-15  ...             12.21             16.93
# 3  Andhra Pradesh  2012-13  ...                NR              0.35
# 4  Andhra Pradesh  2013-14  ...             10.85             11.79
#
# [5 rows x 14 columns]

# %%
dropout.describe()
# Out:
#        State_UT     year  ... HrSecondary_Girls HrSecondary_Total
# count       110      110  ...               110               110
# unique       40        3  ...                76                78
# top       Assam  2013-14  ...                NR                NR
# freq          3       37  ...                34                31
#
# [4 rows x 14 columns]

# %%
dropout_dataUp=dropout[dropout['State_UT']=='Uttar Pradesh']
print(dropout_dataUp.head())
# Out:
#           State_UT     year  ... HrSecondary_Girls HrSecondary_Total
# 98   Uttar Pradesh  2012-13  ...                NR                NR
# 99   Uttar Pradesh  2013-14  ...                NR                NR
# 100  Uttar Pradesh  2014-15  ...              2.45               2.1
#
# [3 rows x 14 columns]

# %%
ax=plt.axes()
ax.set_facecolor('gray')
plt.bar(dropout_dataUp['Primary_Girls'],dropout_dataUp['year'])
plt.xlabel('Primary_Girls')
plt.ylabel('Year')
plt.title('Year based analysis in UP')
plt.show()

# %%
ax=plt.axes()
ax.set_facecolor('lightblue')
plt.bar(dropout_dataUp['Primary_Boys'],dropout_dataUp['year'])
plt.xlabel('Primary_Boys')
plt.ylabel('Y ear')
plt.title('Year based analysis in UP')
plt.show()

# %%
gross.describe()
# Out:
#        Primary_Boys  Primary_Girls  ...  Secondary_Girls  Secondary_Total
# count    110.000000     110.000000  ...       110.000000       110.000000
# mean     102.016909     103.116818  ...        88.476273        87.653091
# std       13.836438      14.136777  ...        15.597699        15.064506
# min       77.420000      69.900000  ...        62.960000        60.080000
# 25%       95.252500      96.107500  ...        78.265000        75.647500
# 50%      100.260000     101.365000  ...        85.100000        85.655000
# 75%      107.240000     107.935000  ...        98.830000        97.407500
# max      145.680000     152.810000  ...       135.390000       127.610000
#
# [8 rows x 9 columns]

# %%
gross['State_UT'].value_counts()
# Out:
# Lakshadweep                  3
# Punjab                       3
# Nagaland                     3
# Himachal Pradesh             3
# Rajasthan                    3
# Meghalaya                    3
# Chandigarh                   3
# Andhra Pradesh               3
# Bihar                        3
# Daman & Diu                  3
# Haryana                      3
# Kerala                       3
# Sikkim                       3
# Tamil Nadu                   3
# Odisha                       3
# Jharkhand                    3
# Goa                          3
# Manipur                      3
# Andaman & Nicobar Islands    3
# Maharashtra                  3
# West Bengal                  3
# Tripura                      3
# Assam                        3
# All India                    3
# Dadra & Nagar Haveli         3
# Gujarat                      3
# Chhattisgarh                 3
# Karnataka                    3
# Jammu And Kashmir            3
# Uttar Pradesh                3
# ...

# %%
gross_dataup=gross[gross['State_UT']=='Uttar Pradesh']
print(gross_dataup.head())
# Out:
#           State_UT     Year  ...  Higher_Secondary_Girls  Higher_Secondary_Total
# 32   Uttar Pradesh  2013-14  ...                   59.91                   61.27
# 69   Uttar Pradesh  2015-16  ...                   59.26                   60.78
# 106  Uttar Pradesh  2014-15  ...                   62.01                   63.75
#
# [3 rows x 14 columns]

# %%
ax=plt.axes()
ax.set_facecolor('lightpink')
plt.bar(gross_dataup['Primary_Girls'],gross_dataup['Year'],color='b')
plt.xlabel('Primary_Girls')
plt.ylabel('Year')
plt.title('Year based analysis in UP')
plt.show()

# %%
ax=plt.axes()
ax.set_facecolor('lightpink')
plt.bar(gross_dataup['Primary_Boys'],gross_dataup['Year'],color='b')
plt.xlabel('Primary_Boys')
plt.ylabel('Year')
plt.title('Year based analysis in UP')
plt.show()

# %%
gross.columns
# Out:
# Index(['State_UT', 'Year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper_Primary_Boys', 'Upper_Primary_Girls', 'Upper_Primary_Total',
#        'Secondary_Boys', 'Secondary_Girls', 'Secondary_Total',
#        'Higher_Secondary_Boys', 'Higher_Secondary_Girls',
#        'Higher_Secondary_Total'],
#       dtype='object')

# %%
gross=gross.replace('NR',0)
gross
# Out:
#                       State_UT  ... Higher_Secondary_Total
# 0    Andaman & Nicobar Islands  ...                 101.28
# 1               Andhra Pradesh  ...                   60.3
# 2            Arunachal Pradesh  ...                  65.27
# 3                        Assam  ...                  32.94
# 4                        Bihar  ...                   23.7
# ..                         ...  ...                    ...
# 105                    Tripura  ...                   43.4
# 106              Uttar Pradesh  ...                  63.75
# 107                Uttaranchal  ...                  80.36
# 108                West Bengal  ...                  49.95
# 109                  All India  ...                  54.21
#
# [110 rows x 14 columns]

# %%
plt.figure(figsize=(15,5))
sns.countplot(dropout['State_UT'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
comps
# Out:
#                       State_UT     year  ...  HrSec_Only  All Schools
# 0    Andaman & Nicobar Islands  2013-14  ...        0.00        53.06
# 1    Andaman & Nicobar Islands  2014-15  ...        0.00        57.25
# 2    Andaman & Nicobar Islands  2015-16  ...        0.00        57.00
# 3               Andhra Pradesh  2013-14  ...       19.32        29.57
# 4               Andhra Pradesh  2014-15  ...       41.60        28.06
# ..                         ...      ...  ...         ...          ...
# 105                West Bengal  2014-15  ...       66.67        12.13
# 106                West Bengal  2015-16  ...       66.67        12.67
# 107                  All India  2013-14  ...       26.65        24.08
# 108                  All India  2014-15  ...       47.96        26.42
# 109                  All India  2015-16  ...       55.72        27.31
#
# [110 rows x 13 columns]

# %%
comps.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Only', 'Primary_with_U_Primary',
#        'Primary_with_U_Primary_Sec_HrSec', 'U_Primary_Only',
#        'U_Primary_With_Sec_HrSec', 'Primary_with_U_Primary_Sec',
#        'U_Primary_With_Sec', 'Sec_Only', 'Sec_with_HrSec.', 'HrSec_Only',
#        'All Schools'],
#       dtype='object')

# %%
comps.loc[0]
# Out:
# State_UT                            Andaman & Nicobar Islands
# year                                                  2013-14
# Primary_Only                                             30.4
# Primary_with_U_Primary                                  73.68
# Primary_with_U_Primary_Sec_HrSec                        89.74
# U_Primary_Only                                              0
# U_Primary_With_Sec_HrSec                                  100
# Primary_with_U_Primary_Sec                              97.92
# U_Primary_With_Sec                                          0
# Sec_Only                                                    0
# Sec_with_HrSec.                                           100
# HrSec_Only                                                  0
# All Schools                                             53.06
# Name: 0, dtype: object

# %%
comps['All Schools']
# Out:
# 0      53.06
# 1      57.25
# 2      57.00
# 3      29.57
# 4      28.06
#        ...
# 105    12.13
# 106    12.67
# 107    24.08
# 108    26.42
# 109    27.31
# Name: All Schools, Length: 110, dtype: float64

# %%
fig = plt.figure(figsize = (25,8)) 
ax=plt.axes()
ax.set_facecolor('lightblue')
plt.bar(x=comps['State_UT'], height= comps['All Schools'],color ='b', width = 0.4) 
plt.xlabel("STATES") 
plt.ylabel("All Schools") 
plt.title("Student enrolled in computer") 
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (25,8)) 
ax=plt.axes()
ax.set_facecolor('lightblue')
plt.bar(x=comps['State_UT'], height= comps['Primary_Only'],color ='g', width = 0.4) 
plt.xlabel("STATES") 
plt.ylabel('Primary_Only') 
plt.title("Student enrolled in computer") 
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (25,8)) 
ax=plt.axes()
ax.set_facecolor('lightpink')
plt.bar(x=comps['State_UT'], height= comps['U_Primary_Only'],color ='g', width = 0.4) 
plt.xlabel("STATES") 
plt.ylabel('U_Primary_Only') 
plt.title("Student enrolled in computer") 
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (25,8)) 
ax=plt.axes()
ax.set_facecolor('yellow')
plt.bar(x=comps['State_UT'], height= comps['Sec_Only'],color ='blue', width = 0.4) 
plt.xlabel("STATES") 
plt.ylabel('Sec_Only') 
plt.title("Student enrolled in computer") 
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (25,8)) 
ax=plt.axes()
ax.set_facecolor('lightblue')
plt.bar(x=comps['State_UT'], height= comps['HrSec_Only'],color ='Blue', width = 0.4) 
plt.xlabel("STATES") 
plt.ylabel('HrSec_Only') 
plt.title("Student enrolled in computer") 
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure(figsize = (25,8)) 
ax=plt.axes()
ax.set_facecolor('lightblue')
plt.bar(x=elect['State_UT'], height= elect['HrSec_Only'],color ='green', width = 0.4) 
plt.xlabel("STATES") 
plt.ylabel('HrSec_Only') 
plt.title("Student enrolled in computer") 
plt.xticks(rotation=90)
plt.show()

# %%
elect
# Out:
#                       State_UT     year  ...  HrSec_Only  All Schools
# 0    Andaman & Nicobar Islands  2013-14  ...        0.00        88.86
# 1    Andaman & Nicobar Islands  2014-15  ...        0.00        88.89
# 2    Andaman & Nicobar Islands  2015-16  ...        0.00        90.10
# 3               Andhra Pradesh  2013-14  ...       91.27        90.34
# 4               Andhra Pradesh  2014-15  ...       93.21        92.76
# ..                         ...      ...  ...         ...          ...
# 105                West Bengal  2014-15  ...       91.67        56.96
# 106                West Bengal  2015-16  ...       91.67        74.88
# 107                  All India  2013-14  ...       91.01        56.78
# 108                  All India  2014-15  ...       92.67        60.01
# 109                  All India  2015-16  ...       92.86        62.81
#
# [110 rows x 13 columns]

# %%
elect.head()
# Out:
#                     State_UT     year  ...  HrSec_Only  All Schools
# 0  Andaman & Nicobar Islands  2013-14  ...        0.00        88.86
# 1  Andaman & Nicobar Islands  2014-15  ...        0.00        88.89
# 2  Andaman & Nicobar Islands  2015-16  ...        0.00        90.10
# 3             Andhra Pradesh  2013-14  ...       91.27        90.34
# 4             Andhra Pradesh  2014-15  ...       93.21        92.76
#
# [5 rows x 13 columns]

# %%
fig = plt.figure(figsize = (20,8)) 
ax=plt.axes()
ax.set_facecolor('lightblue')
plt.bar(x=elect['State_UT'], height= elect['Primary_Only'],color ='g', width = 0.6) 
plt.xlabel("STATES") 
plt.ylabel('Primary_Only') 
plt.title("percentage of electricity within school") 
plt.xticks(rotation=90)
plt.show()

# %%
water
# Out:
#                       State/UT     Year  ...  HrSec_Only  All Schools
# 0    Andaman & Nicobar Islands  2013-14  ...        0.00        98.69
# 1    Andaman & Nicobar Islands  2014-15  ...        0.00        99.52
# 2    Andaman & Nicobar Islands  2015-16  ...        0.00       100.00
# 3               Andhra Pradesh  2013-14  ...       97.52        90.35
# 4               Andhra Pradesh  2014-15  ...       98.37        93.74
# ..                         ...      ...  ...         ...          ...
# 105                West Bengal  2014-15  ...       91.67        97.93
# 106                West Bengal  2015-16  ...      100.00        98.42
# 107                  All India  2013-14  ...       97.14        95.40
# 108                  All India  2014-15  ...       98.23        96.12
# 109                  All India  2015-16  ...       97.92        96.81
#
# [110 rows x 13 columns]

# %%
fig = plt.figure(figsize = (25,8)) 
ax=plt.axes()
ax.set_facecolor('lightblue')
plt.bar(x=water['State/UT'], height= water['Primary_Only'],color ='green', width = 0.6) 
plt.xlabel("STATES") 
plt.ylabel('Primary_Only') 
plt.title("State-wise Analysis of school got water facilities") 
plt.xticks(rotation=90)
plt.show()

# %%
water_dataup=water[water['State/UT']=='Uttar Pradesh']
water_dataup.head()
# Out:
#           State/UT     Year  ...  HrSec_Only  All Schools
# 98   Uttar Pradesh  2013-14  ...      100.00        98.17
# 99   Uttar Pradesh  2014-15  ...      100.00        98.57
# 100  Uttar Pradesh  2015-16  ...       92.86        98.73
#
# [3 rows x 13 columns]

# %%
ax=plt.axes()
ax.set_facecolor('lightblue')
plt.bar(water_dataup['Primary_Only'],water_dataup['Year'],color='g')
plt.xlabel('Primary_Only')
plt.ylabel('Year')
plt.title('Year based analysis in UP')
plt.show()

# %%
out = water.groupby(['State/UT','Year'])['Primary_Only'].sum().reset_index()
out
# Out:
#                       State/UT     Year  Primary_Only
# 0                    All India  2013-14         94.09
# 1                    All India  2014-15         94.88
# 2                    All India  2015-16         95.78
# 3    Andaman & Nicobar Islands  2013-14         98.17
# 4    Andaman & Nicobar Islands  2014-15         99.55
# ..                         ...      ...           ...
# 105                Uttarakhand  2014-15         95.28
# 106                Uttarakhand  2015-16         96.25
# 107                West Bengal  2013-14         97.81
# 108                West Bengal  2014-15         98.00
# 109                West Bengal  2015-16         98.43
#
# [110 rows x 3 columns]

# %%
fig,ax= plt.subplots(figsize=(20,5))
sns.barplot(y='Primary_Only',x='State/UT',data=out,hue='Year',ax=ax)
plt.xticks(rotation=90)
plt.show()

# %%
water.shape
# Out:
# (110, 13)
